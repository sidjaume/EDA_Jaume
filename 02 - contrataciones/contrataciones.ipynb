# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
contrat = pd.read_csv(r'E:\OneDrive\Data Science Bootcamp 2023\jaume_eda\contrataciones finales.csv',encoding='latin-1')
contrat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 14 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   ID                                           220 non-null    int64
#  1   Músico                                       220 non-null    object
#  2   GMV (SIN IVA de MÚSICOS)                     220 non-null    float64
#  3   Comisión + IVA (INGRESOS CON IVA)            220 non-null    float64
#  4   Comisión sin IVA (Ingresos sin IVA o NETOS)  220 non-null    float64
#  5   Fecha bolo                                   204 non-null    object
#  6   De donde viene                               95 non-null     object
#  7   Estado                                       4 non-null      object
#  8   Año-mes contratación                         220 non-null    object
# ...

# %%
contrat.corr(numeric_only=True)
# Out:
#                                                    ID  \
# ID                                           1.000000
# GMV (SIN IVA de MÚSICOS)                    -0.071539
# Comisión + IVA (INGRESOS CON IVA)            0.037075
# Comisión sin IVA (Ingresos sin IVA o NETOS)  0.037074
# Nº Contrataciones                            0.158329
# NUEVO = 1, REPE = 0                         -0.131748
#
#                                              GMV (SIN IVA de MÚSICOS)  \
# ID                                                          -0.071539
# GMV (SIN IVA de MÚSICOS)                                     1.000000
# Comisión + IVA (INGRESOS CON IVA)                            0.954588
# Comisión sin IVA (Ingresos sin IVA o NETOS)                  0.954589
# Nº Contrataciones                                           -0.233897
# NUEVO = 1, REPE = 0                                          0.208649
#
#                                              Comisión + IVA (INGRESOS CON IVA)  \
# ...

# %%
contrat['Músico'].value_counts().head(10)
# Out:
# Músico
# Guilan            11
# Arde la Calle      9
# Rock Olas          7
# Rustica            6
# Spin Off           6
# David Zayas        5
# Joey               5
# Alejandro Rosa     5
# Javi del Val       4
# Amedias            4
# Name: count, dtype: int64

# %%
sns.pairplot(contrat.iloc[:,1:]);

# %%
contrat
# Out:
#       ID                 Músico  GMV (SIN IVA de MÚSICOS)  \
# 0      1            Betto Jones                    123.97
# 1      2            Luis Retana                    272.73
# 2      3            Yai Machine                    190.08
# 3      4            Eleka Shows                    247.93
# 4      5         Zao Night Band                    785.12
# ..   ...                    ...                       ...
# 215  216         Alejandro Rosa                    289.26
# 216  217            Rober Marcu                    100.00
# 217  218         Alejandro Rosa                    100.00
# 218  219                 Guilan                    280.99
# 219  220  Cada loco con su tema                    578.51
#
#      Comisión + IVA (INGRESOS CON IVA)  \
# 0                                 22.5
# 1                                 49.5
# 2                                 34.5
# 3                                 45.0
# 4                                  0.0
# ...
