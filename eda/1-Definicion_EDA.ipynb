# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# # Análisis de contratación de músicos en Fander: Explorando patrones y preferencias

# %% [markdown]
# ### TEMA

# %% [markdown]
# ##### El análisis exploratorio de datos se centra en una plataforma web de catálogo de músicos. Se abordarán diversas preguntas relacionadas con las solicitudes a músicos, perfiles de músicos, restaurantes con música en vivo y datos adicionales obtenidos de Google.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# El objetivo es identificar patrones, preferencias y tendencias en la contratación de músicos, así como obtener información relevante para optimizar la experiencia de los usuarios y la oferta de servicios en la plataforma.

# %% [markdown]
# Para ello, primero haremos un análisis respondiendo a una serie de preguntas.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una breve descripción del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %% [markdown]
# La fuente está extraída de las bases de datos de la empresa Fander.

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
import pandas as pd

# %% [markdown]
# #### Musicos registrados en la web

# %%
musicos = pd.read_csv(r'E:\OneDrive\Data Science Bootcamp 2023\jaume_eda\01 - musicos\musicos.csv',encoding='latin-1')
musicos.head()
# Out:
#      id        Date                    Title  musico_nombre_artistico  \
# 0  4679  2022-02-15                     Alex                     Alex
# 1  4706  2022-02-15                 DJ_movil                 DJ_movil
# 2  4914  2022-02-16  Paloma García del Busto  Paloma García del Busto
# 3  5005  2022-02-16     Platos &amp; Piñones         Platos & Piñones
# 4  5020  2022-02-17            Pablo Pedraza            Pablo Pedraza
#
#   musico_provincia musico_tipo  \
# 0            Cádiz      Músico
# 1           Madrid          DJ
# 2           Madrid      Músico
# 3           Madrid      Músico
# 4           Madrid      Músico
#
#                          musico_formatos_disponibles  musico_precio_minimo_dj  \
# 0  a:2:{i:0;s:7:"Solista";i:1;s:27:"Banda/Conjunt...                      NaN
# 1                                                NaN                    100.0
# 2  a:5:{i:0;s:7:"Solista";i:1;s:4:"Dúo";i:2;s:5:"...                      NaN
# ...

# %% [markdown]
# #### Registro de contrataciones hechas a músicos

# %%
contrat = pd.read_csv(r'E:\OneDrive\Data Science Bootcamp 2023\jaume_eda\02 - contrataciones\contrataciones finales.csv',encoding='latin-1')
contrat.head()
# Out:
#    ID          Músico  GMV (SIN IVA de MÚSICOS)  \
# 0   1     Betto Jones                    123.97
# 1   2     Luis Retana                    272.73
# 2   3     Yai Machine                    190.08
# 3   4     Eleka Shows                    247.93
# 4   5  Zao Night Band                    785.12
#
#    Comisión + IVA (INGRESOS CON IVA)  \
# 0                               22.5
# 1                               49.5
# 2                               34.5
# 3                               45.0
# 4                                0.0
#
#    Comisión sin IVA (Ingresos sin IVA o NETOS)  Fecha bolo De donde viene  \
# 0                                        18.60   8/10/2022            NaN
# 1                                        40.91  16/10/2022            NaN
# 2                                        28.51  16/10/2022            NaN
# 3                                        37.19  22/10/2022            NaN
# ...

# %% [markdown]
# #### Solicitudes para contratar músicos

# %%
sol_musicos = pd.read_csv(r'E:\OneDrive\Data Science Bootcamp 2023\jaume_eda\03 - solicitudes_musicos\solicitudes_musicos.csv',encoding='latin-1')
sol_musicos.head()
# Out:
#       id        Date                     Title  \
# 0  31796  2023-03-10                       NaN
# 1  31798  2023-03-10                       NaN
# 2  31799  2023-03-10                       NaN
# 3  31800  2023-03-10                       NaN
# 4  31801  2023-03-10  Mensaje de  a Serotonina
#
#   calculadora_musico_nombre_artistico calculadora_musico_provincia  \
# 0                            Eva Páez                          NaN
# 1                            Spin Off                          NaN
# 2                      Kilometro cero                          NaN
# 3                         Crazy Cabin                       Madrid
# 4                          Serotonina                          NaN
#
#   calculadora_musico_tipo calculadora_provincia_evento  \
# 0                  Músico                          NaN
# 1                  Músico                          NaN
# 2                  Músico                          NaN
# ...

# %% [markdown]
# #### Registro de restaurantes en Madrid.

# %%
resto = pd.read_csv(r'E:\OneDrive\Data Science Bootcamp 2023\jaume_eda\04 - restaurantes\restaurantes.csv',encoding='latin-1')
resto.head()
# Out:
#    ID           Nombre Restaurante  \
# 0   1    ABYA - Palacio de Saldaña
# 1   2              Aguirre Pozuelo
# 2   3          Alejandro Aranzábal
# 3   4  Almadraba Rivas Restaurante
# 4   5                Amor al Plato
#
#                                            Dirección  Distrito Postal  \
# 0       C. de José Ortega y Gasset, 32, 28006 Madrid          28006.0
# 1  C. Segundo Mata, 1, 28224 Pozuelo de Alarcón, ...          28224.0
# 2                                                NaN              NaN
# 3            Rivas Vaciamadrid Avenida la técnica 43          28522.0
# 4           Calle Capitán Blanco Argibay, 88, Madrid          28029.0
#
#              Localidad Provincia
# 0               Madrid    Madrid
# 1   Pozuelo de Alarcón    Madrid
# 2                  NaN    Madrid
# 3  Rivas - Vaciamadrid    Madrid
# 4               Madrid    Madrid

# %% [markdown]
# #### Tráfico en la web según ciudad

# %%
trafico = pd.read_csv(r'E:\OneDrive\Data Science Bootcamp 2023\jaume_eda\05 - trafico\trafico.csv',encoding='latin-1')
trafico.head()
# Out:
#       Ciudad  Usuarios  Usuarios nuevos  Sesiones con interacción  \
# 0  (not set)     13126            76598                     12927
# 1     Madrid      3267             2938                      3402
# 2  Barcelona      1637             1413                      1427
# 3    Seville       695              616                       503
# 4   Valencia       693              605                       835
#
#    Porcentaje de interacciones  Sesiones con interacción por usuario  \
# 0                 8.934891e+15                          9.848393e+14
# 1                 6.195593e+14                          1.041322e+16
# 2                 6.041490e+15                          8.717166e+15
# 3                 5.576497e+15                          7.237410e+15
# 4                 6.508184e+15                          1.204906e+15
#
#    Tiempo de interacción medio  Número de eventos  Conversiones  \
# 0                 9.645551e+15             267488          5430
# ...
