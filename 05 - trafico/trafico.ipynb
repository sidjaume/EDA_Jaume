# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
trafico = pd.read_csv(r'E:\OneDrive\Data Science Bootcamp 2023\jaume_eda\trafico.csv',encoding='latin-1')
trafico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464 entries, 0 to 463
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Ciudad                                464 non-null    object
#  1   Usuarios                              464 non-null    int64
#  2   Usuarios nuevos                       464 non-null    int64
#  3   Sesiones con interacción              464 non-null    int64
#  4   Porcentaje de interacciones           464 non-null    float64
#  5   Sesiones con interacción por usuario  464 non-null    float64
#  6   Tiempo de interacción medio           464 non-null    float64
#  7   Número de eventos                     464 non-null    int64
#  8   Conversiones                          464 non-null    int64
#  9   Total de ingresos                     464 non-null    int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 36.4+ KB

# %%
trafico
# Out:
#            Ciudad  Usuarios  Usuarios nuevos  Sesiones con interacción  \
# 0       (not set)     13126            76598                     12927
# 1          Madrid      3267             2938                      3402
# 2       Barcelona      1637             1413                      1427
# 3         Seville       695              616                       503
# 4        Valencia       693              605                       835
# ..            ...       ...              ...                       ...
# 459  Beaver Falls         0                0                         0
# 460     Edinburgh         0                0                         1
# 461      Florence         0                0                         0
# 462        Temuco         0                0                         0
# 463          Thun         0                0                         0
#
#      Porcentaje de interacciones  Sesiones con interacción por usuario  \
# ...
