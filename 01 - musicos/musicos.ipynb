# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
musicos = pd.read_csv(r'E:\OneDrive\Data Science Bootcamp 2023\jaume_eda\musicos.csv',encoding='latin-1')
musicos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2023 entries, 0 to 2022
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     2023 non-null   int64
#  1   Date                                   2023 non-null   object
#  2   Title                                  2023 non-null   object
#  3   musico_nombre_artistico                2019 non-null   object
#  4   musico_provincia                       2019 non-null   object
#  5   musico_tipo                            1993 non-null   object
#  6   musico_formatos_disponibles            1875 non-null   object
#  7   musico_precio_minimo_dj                515 non-null    float64
#  8   musico_coste_hora_extra_dj             516 non-null    float64
#  9   musico_precio_minimo_solista           646 non-null    float64
# ...

# %%
musicos.corr(numeric_only=True)
# Out:
#                                              id  musico_precio_minimo_dj  \
# id                                     1.000000                 0.095271
# musico_precio_minimo_dj                0.095271                 1.000000
# musico_coste_hora_extra_dj             0.054886                 0.317259
# musico_precio_minimo_solista           0.004017                 1.000000
# musico_coste_hora_extra_solista        0.013700                 1.000000
# musico_precio_minimo_duo              -0.043959                      NaN
# musico_coste_hora_extra_duo           -0.056487                      NaN
# musico_precio_minimo_trio             -0.116431                      NaN
# musico_coste_hora_extra_trio           0.058515                      NaN
# musico_precio_minimo_cuarteto         -0.081078                      NaN
# musico_coste_hora_extra_cuarteto      -0.107330                      NaN
# musico_precio_minimo_conjunto         -0.088620                      NaN
# ...

# %%
musicos
# Out:
#          id        Date                    Title  musico_nombre_artistico  \
# 0      4679  2022-02-15                     Alex                     Alex
# 1      4706  2022-02-15                 DJ_movil                 DJ_movil
# 2      4914  2022-02-16  Paloma García del Busto  Paloma García del Busto
# 3      5005  2022-02-16     Platos &amp; Piñones         Platos & Piñones
# 4      5020  2022-02-17            Pablo Pedraza            Pablo Pedraza
# ...     ...         ...                      ...                      ...
# 2018  44054  2023-06-19             ESCLATAFOLKS             ESCLATAFOLKS
# 2019  44227  2023-06-19             Lara Morello             Lara Morello
# 2020  44438  2023-06-19            Bohemian club            Bohemian club
# 2021  44507  2023-06-20           Carlos del Río           Carlos del Río
# 2022  44683  2023-06-20               Arre-Molke               Arre-Molke
#
#      musico_provincia musico_tipo  \
# 0               Cádiz      Músico
# ...

# %%
musicos = musicos[musicos['musico_provincia'] == 'Madrid']
musicos[['id','musico_nombre_artistico','musico_provincia']].sort_values(by='musico_nombre_artistico',ascending=True)
# Out:
#          id     musico_nombre_artistico musico_provincia
# 953   15651  ***Mariachi* Edwin Agudelo           Madrid
# 739   12197                  2The Sound           Madrid
# 424    8727                 80 RedNecks           Madrid
# 538    9597                     A Tempo           Madrid
# 623   10040                     AMEDIAS           Madrid
# ...     ...                         ...              ...
# 1137  18576                      Ángulo           Madrid
# 1993  42518           Ídolos del parque           Madrid
# 258    6681                Óscar Laguía           Madrid
# 122    6065                     Óscar X           Madrid
# 1967  38189                 ámame vacío           Madrid
#
# [495 rows x 3 columns]
